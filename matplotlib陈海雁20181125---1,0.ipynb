# %%
import numpy as np
import matplotlib.pyplot as plt
#%mat.是一个魔法函数,有了这个,就可以省略plt.show()了
# %matplotlib inline

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.xlabel('xlabel',fontsize=30)
plt.ylabel('ylabel',fontsize=50)
# Out:
# Text(0,0.5,'ylabel')

# %% [markdown]
# 不同的线条

# %% [markdown]
# 字符|类型 | 字符|类型
# ---|--- | --- | ---
# `  '-'	`| 实线 | `'--'`|	虚线
# `'-.'`|	虚点线 | `':'`|	点线
# `'.'`|	点 | `','`| 像素点
# `'o'`	|圆点 | `'v'`|	下三角点
# `'^'`|	上三角点 | `'<'`|	左三角点
# `'>'`|	右三角点 | `'1'`|	下三叉点
# `'2'`|	上三叉点 | `'3'`|	左三叉点
# `'4'`|	右三叉点 | `'s'`|	正方点
# `'p'`	| 五角点 | `'*'`|	星形点
# `'h'`|	六边形点1 | `'H'`|	六边形点2
# `'+'`|	加号点 | `'x'`|	乘号点
# `'D'`|	实心菱形点 | `'d'`|	瘦菱形点
# `'_'`|	横线点 | |

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'4')
#plt.plot([1,2,3,4,5],[0,3,7,14,23],'2')
plt.plot([1,2,3,4,5],[0,3,7,14,23],'d')

# %%
x=np.linspace(-10,10)
y=np.sin(x)
plt.plot(x,y,linewidth=(5.0))

# %%
plt.plot(x,y,color='b',linestyle=':',marker='o',markerfacecolor='r',markersize=10)

# %%
line=plt.plot(x,y)
plt.setp(line,color='r',linewidth=2.0,alpha=0.9)
# Out:
# [None, None, None]

# %%
plt.subplot(221)
plt.subplot(224)
#plt.subplot(213)

# %%
plt.subplot(321)
plt.subplot(324)

# %%
plt.plot(x,y,color='b',linestyle=':',marker = 'o',markerfacecolor='r',markersize = 10)
plt.xlabel('x:---')
plt.ylabel('y:---')
plt.title('tang yu di:---')
plt.text(0,0,'tang yu di')
plt.grid(True)
plt.annotate('tangyudi',xy=(-5,0),xytext=(-2,0.3),arrowprops = dict(facecolor='red',shrink=0.05,headlength= 20,headwidth = 20))
# Out:
# Text(-2,0.3,'tangyudi')
